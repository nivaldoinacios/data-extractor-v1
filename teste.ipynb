# %%
from df_statistics import *
from df_base import *
import pandas as pd

df = pd.merge(df, pd_df, how='outer', on=['MAC'])

print(df)
# Out:
# Antigo ->  37488261
# Novo ->  120703
# Antigo ->  95309868
# Novo ->  31422792
# Antigo ->  13134397
# Novo ->  2477
# Antigo ->  208418202
# Novo ->  115438
# Antigo ->  5576222
# Novo ->  682232
# Antigo ->  935230267
# Novo ->  873268
# Antigo ->  1531443616
# Novo ->  183251
# Antigo ->  54827306
# Novo ->  7962474
# Antigo ->  52202
# Novo ->  8221
# Antigo ->  181552474
# Novo ->  1672765
# Antigo ->  1238158
# Novo ->  31591
# Antigo ->  238880
# Novo ->  4877
# Antigo ->  253458610
# Novo ->  3896044
# Antigo ->  11189576
# Novo ->  6830171
# Antigo ->  29504959
# Novo ->  1258389
# Antigo ->  230181561
# Novo ->  12754477
# Antigo ->  738547784
# Novo ->  312440
# Antigo ->  1264
# Novo ->  1024
# Antigo ->  1808603743
# Novo ->  282734
# Antigo ->  453462976
# Novo ->  33859
# Antigo ->  4202910
# Novo ->  135056
# Antigo ->  45807969
# Novo ->  6549
# Antigo ->  204657093
# Novo ->  8881442
# Antigo ->  289798793
# Novo ->  287982
# Antigo ->  125117752
# Novo ->  240
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 33
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UserID             34 non-null     object
#  1   Username           34 non-null     object
#  2   IPADDRESS          34 non-null     object
#  3   MAC                34 non-null     object
#  4   Status             34 non-null     object
#  5   AP_ID              34 non-null     object
#  6   AP_NAME            34 non-null     object
#  7   RF/WLAN            34 non-null     object
#  8   BAND               34 non-null     object
#  9   Type               34 non-null     object
#  10  RX/TX              34 non-null     object
#  11  RSSI               34 non-null     object
#  12  VLAN               34 non-null     object
#  13  SSID               34 non-null     object
#  14  @timestamp-py      34 non-null     object
#  15  PCKT_SENT          34 non-null     object
# ...
